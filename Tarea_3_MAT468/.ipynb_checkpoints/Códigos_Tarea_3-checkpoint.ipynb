# %% [markdown]
# # Tarea 3
# ## Simulación Estocástica
# ### Fabián Ramírez

# %% [markdown]
# **Problema 1** Aplicar Algoritmo 3

# %%
# Random walk sampler
library('heavy')

# %%
# Creamos un programa para generar la muestra:
alg_3 = function(){
k=1/20216.335877
f = function(x) (
    k*exp(
        -(
            (x[1]*x[2])^2 + (x[1])^2 + (x[2])^2 - 8*x[1] - 8*x[2]
        )/2
    )
)
t=1
M=10^5
xt = c(0.9242179,2.285951) # x1
X1t = c(xt[1])
Sigma = matrix(c(1,0,0,1), ncol = 2)
while (t<M){
    z = rmnorm(1,Sigma=Sigma)
    y = xt + 2*z
    p = min(f(y)/f(xt),1)
    u = runif(1,0,1)
    if (u<=p){
        xt = y
    } else {
        xt = xt
    }
    X1t = cbind(X1t,xt[1])
    # Agregar un paso
    t=t+1
}
return(mean(X1t))
}

# %%
alg_3()
# Out:
# [1] 1.84781

# %%
alg_3()
# Out:
# [1] 1.791049

# %%
alg_3()
# Out:
# [1] 1.877199

# %% [markdown]
# **Problema 2** Aplicar Algoritmo 5

# %%
Xt = rbind(c(1.1,1.3))
M=10^5
t=1
while (t<=M){
    z = rnorm(1)
    a = 1/(1+Xt[t,1]^2)
    yt = 4*a + z*sqrt(a)
    b = 1/(1+Xt[t,2]^2)
    xt = 4*b + z*sqrt(b)
    Xt = rbind(Xt,c(xt,yt))
    t=t+1
}
Xt
# Out:
#       [,1]         [,2]
#  [1,]  1.100000000 1.30000000
#  [2,]  2.243855970 2.64498007
#  [3,] -0.003745923 0.08267486
#  [4,]  5.224233314 5.25559272
#  [5,]  0.101151078 0.10255089
#  [6,]  3.168974212 3.16998009
#  [7,]  0.194187879 0.19434847
#  [8,]  3.927235157 3.92746911
#  [9,]  0.671256926 0.67130810
# [10,]  3.239675710 3.23981774
# [11,]  0.225587341 0.22561030
# [12,]  1.970982969 1.97101144
# [13,]  0.143931743 0.14394280
# [14,]  5.636218651 5.63623355
# [15,]  0.276505379 0.27650640
# [16,]  5.256949438 5.25695179
# [17,]  0.280194139 0.28019432
# [18,]  1.949825512 1.94982578
# [19,]  0.808498244 0.80849842
# [20,]  0.747325947 0.74732622
# [21,]  2.421810039 2.42181070
# [22,]  1.213905483 1.21390590
# [23,]  0.851645507 0.85164601
# [24,]  2.796881032 2.79688231
# [25,]  0.996049404 0.99604999
# [26,]  1.089029905 1.08903081
# [27,]  1.566254168 1.56625571
# [28,]  2.409446951 2.40944944
# [29,]  0.486391852 0.48639280
# [30,]  5.419617633 5.41962085
# [31,] ...          ...
# [32,]  2.63837969   2.63837969
# [33,]  0.43269175   0.43269175
# [34,]  4.02760913   4.02760913
# [35,] -0.01370908  -0.01370908
# [36,]  3.75252453   3.75252453
# [37,]  0.25652848   0.25652848
# [38,]  1.91077153   1.91077153
# [39,]  0.36938649   0.36938649
# [40,]  3.33963148   3.33963148
# [41,]  0.09551208   0.09551208
# [42,]  3.66920749   3.66920749
# [43,]  0.44206998   0.44206998
# [44,]  4.76697091   4.76697091
# [45,]  0.07314664   0.07314664
# [46,]  3.61906806   3.61906806
# [47,] -0.25319182  -0.25319182
# [48,]  3.42172604   3.42172604
# [49,]  0.20145078   0.20145078
# [50,]  4.74868796   4.74868796
# [51,]  0.26915277   0.26915277
# [52,]  3.75255264   3.75255264
# [53,]  0.44614890   0.44614890
# [54,]  3.66807701   3.66807701
# [55,]  0.57802371   0.57802371
# [56,]  1.63672441   1.63672441
# [57,]  1.49617753   1.49617753
# [58,]  1.42998661   1.42998661
# [59,]  1.10730372   1.10730372
# [60,]  1.60249790   1.60249790
# [61,]  0.85075916   0.85075916
